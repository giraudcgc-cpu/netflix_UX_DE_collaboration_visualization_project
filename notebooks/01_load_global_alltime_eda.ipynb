# %% [markdown]
# # Global Weekly EDA
#
# ## Load Data

# %%
import pandas as pd
import duckdb
from pathlib import Path

# %%
import openpyxl
print("openpyxl is working") # for reading excel files
# Out:
# openpyxl is working

# %%
DATA_PATH = Path("../data/bronze")
df = pd.read_excel(DATA_PATH / "global_weekly.xlsx")
# Out:
# c:\Users\adelo\de25\Netflix_Analytics_DE_UX\.venv\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
con = duckdb.connect("../database/netflix.duckdb")
# Out:
# ---------------------------------------------------------------------------
# IOException                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 con = duckdb.connect("../database/netflix.duckdb")
#
# IOException: IO Error: Cannot open file "\\?\C:\Users\adelo\de25\Netflix_Analytics_DE_UX\database\netflix.duckdb": The system cannot find the path specified.

# %% [markdown]
# ## Inspect DataFrame and Table

# %%
df.head()
# Out:
#   country_name country_iso2        week category  weekly_rank  \
# 0    Argentina           AR  2026-03-15    Films            1
# 1    Argentina           AR  2026-03-15    Films            2
# 2    Argentina           AR  2026-03-15    Films            3
# 3    Argentina           AR  2026-03-15    Films            4
# 4    Argentina           AR  2026-03-15    Films            5
#
#               show_title season_title  cumulative_weeks_in_top_10
# 0            War Machine          NaN                           2
# 1  Strangers in the Park          NaN                           2
# 2    Joker: Folie à Deux          NaN                           1
# 3   Trolls Band Together          NaN                           2
# 4        Double Jeopardy          NaN                           1

# %%
df.shape
# Out:
# (458260, 8)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 458260 entries, 0 to 458259
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   country_name                458260 non-null  str
#  1   country_iso2                458260 non-null  str
#  2   week                        458260 non-null  str
#  3   category                    458260 non-null  str
#  4   weekly_rank                 458260 non-null  int64
#  5   show_title                  458260 non-null  str
#  6   season_title                223904 non-null  str
#  7   cumulative_weeks_in_top_10  458260 non-null  int64
# dtypes: int64(2), str(6)
# memory usage: 28.0 MB

# %% [markdown]
# ## Check for NULLS and duplicates

# %%
df.isnull().sum()
# Out:
# country_name                       0
# country_iso2                       0
# week                               0
# category                           0
# weekly_rank                        0
# show_title                         0
# season_title                  234356
# cumulative_weeks_in_top_10         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Analysis

# %%
df.describe()
# Out:
#          weekly_rank  cumulative_weeks_in_top_10
# count  458260.000000               458260.000000
# mean        5.500000                    3.442231
# std         2.872284                    6.057246
# min         1.000000                    1.000000
# 25%         3.000000                    1.000000
# 50%         5.500000                    2.000000
# 75%         8.000000                    3.000000
# max        10.000000                  127.000000

# %%
df["category"].value_counts()
# Out:
# category
# Films    229130
# TV       229130
# Name: count, dtype: int64

# %%
df["country_name"].nunique()
# Out:
# 94

# %%
df["week"].min(), df["week"].max()
# Out:
# ('2021-07-04', '2026-03-15')

# %%
df.sort_values("weekly_rank").head(10)
# Out:
#               country_name country_iso2        week category  weekly_rank  \
# 274930       New Caledonia           NC  2022-01-23       TV            1
# 274970       New Caledonia           NC  2022-01-09       TV            1
# 458220             Vietnam           VN  2021-07-11    Films            1
# 60               Argentina           AR  2026-02-22    Films            1
# 274990       New Caledonia           NC  2022-01-02       TV            1
# 274900       New Caledonia           NC  2022-01-30    Films            1
# 274950       New Caledonia           NC  2022-01-16       TV            1
# 397110              Sweden           SE  2023-07-09       TV            1
# 91690   Dominican Republic           DO  2023-03-19       TV            1
# 397130              Sweden           SE  2023-07-02       TV            1
#
#                                    show_title                season_title  \
# 274930                             Archive 81        Archive 81: Season 1
# 274970                             Stay Close  Stay Close: Limited Series
# 458220  Fast & Furious Presents: Hobbs & Shaw                         NaN
# 60                                  Firebreak                         NaN
# 274990                            The Witcher       The Witcher: Season 2
# 274900                    The Royal Treatment                         NaN
# 274950                             Stay Close  Stay Close: Limited Series
# 397110                            The Witcher       The Witcher: Season 3
# 91690                               The Glory         The Glory: Season 1
# 397130                            The Witcher       The Witcher: Season 3
#
#         cumulative_weeks_in_top_10
# 274930                           1
# 274970                           2
# 458220                           1
# 60                               1
# 274990                           3
# 274900                           2
# 274950                           3
# 397110                           2
# 91690                            3
# 397130                           1
